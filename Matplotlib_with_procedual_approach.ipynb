# %% [markdown]
# # Matplotlib Introduction

# %% [markdown]
# # Line Plot

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
x=[0,1,2,3,4]

y=[0,2,4,6,8]

#plt.figure(figsize=(1.5,1.5),dpi=250)
plt.figure(figsize=(6,5))
#plt.plot(x,y,label='2x',color='red',linewidth=1,marker='^',linestyle='--',markersize='12',markeredgecolor='blue')
plt.plot(x,y,'r^--')

#plt.title("Graph",fontdict={'fontname':'Comic Sans Ms','fontsize':20})
#plt.title("Graph1",color='g')
plt.title("Graph",fontname='Comic Sans Ms',fontsize=20)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10])
#plt.legend()
plt.show()

# %% [markdown]
# # Plotting two lines in same Graph

# %%
# Plotting two lines in same Graph
x=np.arange(0,10,1)
y1= 2*x + 2
y2= 3*x + 3
plt.plot(x, y1, label = "Line 1", color='g')
plt.plot(x, y2, label = "Line 2", color='r')
plt.legend()
plt.show()

# %% [markdown]
# # Creating Multiplots on Same Canvas

# %%
# plt.subplot(nrows, ncols, plot_number)
x = np.linspace(0, 5, 11)
print(x)
type(x)
y = x ** 2
plt.subplot(1,2,1)
plt.plot(x, y, 'r--') # More on color options later
plt.subplot(1,2,2)
plt.plot(y, x, 'g*-');
# Out:
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]

# %%
# plt.subplot(nrows, ncols, plot_number)
x = np.linspace(0, 5, 11)
print(x)
type(x)
y = x ** 2
plt.subplot(2,1,1)
plt.plot(x, y, 'r--') # More on color options later
plt.subplot(2,1,2)
plt.plot(y, x, 'g*-');
# Out:
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]

# %% [markdown]
# # Bar Plot

# %%
x=['A','B','C']
y=[1,4,3]

bar=plt.bar(x,y)
bar[0].set_hatch('/')
bar[1].set_hatch('o')
bar[2].set_hatch('*')
#plt.yticks([1,4,3])

# %%
x=['A','B','C']
y=[1,4,3]

plt.barh(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
df = pd.DataFrame({'Number_of_Males': [10, 15, 25, 14],
                   'Number_of_Females': [20, 25, 15,10]},
                  index=['Italian', 'Indian', 'Mexican', 'Chinese'])

# Plot stacked horizontal bar chart
df.plot(kind="barh", title="Gender wise Cuisine preference chart",
        color={"green", "pink"})

# %%
df = pd.DataFrame({'Number_of_Males': [10, 15, 25, 14],
                   'Number_of_Females': [20, 25, 15,10],
                  'country':['Italian', 'Indian', 'Mexican', 'Chinese']})
print(df)
plt.bar(df.country,df.Number_of_Males,color='r')
plt.bar(df.country,df.Number_of_Females,color='b',alpha=0.2)
#plt.plot(gas.Year, gas.USA, 'b.-', label='United States')
# Out:
#    Number_of_Males  Number_of_Females  country
# 0               10                 20  Italian
# 1               15                 25   Indian
# 2               25                 15  Mexican
# 3               14                 10  Chinese
# <BarContainer object of 4 artists>

# %% [markdown]
# # Pie Chart

# %%
pies= ["apple", "cheesecake", "pecan", "chocolate"]
boxes=[50, 25, 35, 19]
mycolors = ["black", "hotpink", "b", "#4CAF50"]
# Pie Chart
plt.pie(boxes,labels=pies,colors=mycolors)
plt.title("Pie Chart")
plt.legend(title='Fruits')
plt.show()

# %%
# Customitions
# Data
pies= ["apple", "cheesecake", "pecan", "chocolate"]
boxes=[50, 25, 35, 19]
outside = (0, 0, 0.5, 0) # Only explode on second slice
# Pie Chart
#startangle to start first data rotated 90 degree counterclcokwise from x-axis
plt.pie(boxes, labels=pies, explode=outside, autopct="%.1f", shadow=True, startangle=90) 
plt.title("Pie Chart")
plt.show()

# %% [markdown]
# # Area Plot

# %%
# Basic Area Plot

# Import Libraries

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Data
x=np.arange(0,10,1)
y= 3*x + 3

# Plot Data
plt.stackplot(x,y)
plt.show()

# %%
# Customizations: Alpha is opacity

# Import Libraries

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Data
x=np.arange(0,10,1)
y= 3*x + 3

# Changing Figure Size
fig=plt.figure(figsize=(10,5))

# Plot Data
plt.stackplot(x,y, linewidth=2.0, linestyle=":", color='red', alpha=0.5)
plt.title("Area Plot")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.legend(["Line"], loc='best') # left,right,center=10,upper right
plt.legend(["Line"], loc='upper left')
plt.grid(True)
plt.show()

# %%
# Plotting two area plots in same Graph
x=np.arange(0,10,1)
y1= 2*x + 2
y2= 3*x + 3

plt.stackplot(x, y2, color='b')
plt.stackplot(x, y1, color='y')
#plt.stackplot(x, y2, color='r',alpha=0.2)
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
# Data
a=[30,40,50,60,70,80]
b=[4,5,2,9,10,12]

c=[1,2,3,4,3,2]

# Create Scatter Plot
plt.scatter(a,b,color='red')
plt.scatter(a,c)
plt.show()

# %%
# Customizations

# Data
a=[10,20,30,50,70,90]
b=[4,5,2,9,10,12]

c=[1,2,3,4,3,2]

# Create Scatter Plot
plt.scatter(a,b,c='pink', s=100, edgecolors='y', marker='o', alpha=0.8)
plt.scatter(a,c, c='red', s=300, edgecolors='b', marker='*', alpha=1)
plt.legend(['b', 'x'], loc='best')
plt.title("Scatter Plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid()
plt.show()

# %% [markdown]
# # Box Plot

# %%
# Data

price=[50, 55, 20, 65, 45, 60, 54, 70, 67, 100]
discount=[10, 15,11,20, 25, 65, 12, 17, 19, 2]
total=[100, 120, 135, 50, 200, 110, 120, 167, 130, 115]
data=list([price, discount, total])

# Box Plot
plt.boxplot(data, showmeans=True)
plt.title("Box Plot")
plt.grid(True)
plt.show()

# %%
df = pd.DataFrame({'Number_of_Males': [10, 15, 25, 14],
                   'Number_of_Females': [20, 25, 15,10],
                  })
df.plot.box();

#plt.figure(1,figsize(14,4))
'''for i in range (1,3):
    plt.subplot(1,2,i)
    plt.boxplot(df[df.columns[i]])
    plt.title(df.columns[i])
plt.show()'''
# Out:
# 'for i in range (1,3):\n    plt.subplot(1,2,i)\n    plt.boxplot(df[df.columns[i]])\n    plt.title(df.columns[i])\nplt.show()'

# %% [markdown]
# # Working with Dataframes

# %%
gas = pd.read_csv('gas_prices.csv')
gas.head(2)
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16     1.0
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46     1.3
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14

# %%
plt.figure(figsize=(8,5))

plt.title('Gas Prices over Time (in USD)', fontdict={'fontweight':'bold', 'fontsize': 18})

plt.plot(gas.Year, gas.USA, 'b.-', label='United States')
plt.plot(gas.Year, gas.Canada, 'r.-',label='Canada')
plt.plot(gas.Year, gas['South Korea'], 'g.-')
plt.plot(gas.Year, gas.Australia, 'y.-')

# Another Way to plot many values!
# countries_to_look_at = ['Australia', 'USA', 'Canada', 'South Korea']
# for country in gas:
#     if country in countries_to_look_at:
#         plt.plot(gas.Year, gas[country], marker='.')

#plt.xticks(gas.Year[::3].tolist()+[2011])
plt.xticks(gas.Year[::3].tolist())
plt.xlabel('Year')
plt.ylabel('US Dollars')

plt.legend()

plt.savefig('Gas_price_figure.png', dpi=300)

plt.show()

# %%
years=gas['Year'].tolist()
#years= df['Year'].tolist()
print(years)
print(years[::3])

# %%
fifa = pd.read_csv('fifa_data.csv')

fifa.head(5)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
bins = [40,50,60,70,80,90,100]

plt.figure(figsize=(8,5))

plt.hist(fifa.Overall, bins=bins, color='#abcdef')

plt.xticks(bins)

plt.ylabel('Number of Players')
plt.xlabel('Skill Level')
plt.title('Distribution of Player Skills in FIFA 2018')

plt.savefig('histogram.png', dpi=300)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
 
x = np.arange(0, 10, 0.1)
y = np.sin(np.pi * x) + x
 
fig, ax = plt.subplots(1)
ax.plot(x, y)
#ax.set_xlabel("x")
ax.set_
ax.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')
